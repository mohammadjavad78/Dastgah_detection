# %%
import librosa
import os
from KNN import *
from PCA import *
from LDA import *
from SVM import *
import pickle
import pandas as pd

# %%
with open('X.pickle', 'rb') as f: #loads the file from hard disk
    X = pickle.load(f)
    
with open('label1.pickle', 'rb') as f: #loads the file from hard disk
    label1 = pickle.load(f)
    
with open('label2.pickle', 'rb') as f: #loads the file from hard disk
    label2 = pickle.load(f)

# %%
knn=KNN(X,label2,1/3)

# %%
knn.plot(50)
# Out:
# The best accuracy is 35.06 % with k = 1

# %%
pc=pca(X,pd.DataFrame(label2))

# %%
X,y=pc.PCAout(15)

# %%
ld=lda(X,pd.DataFrame(label2))

# %%
X,y=ld.LDAout()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
knn=KNN(X,label2,1/3)

# %%
knn.plot(50)
# Out:
# The best accuracy is 29.44 % with k = 20

# %%
knn.accurate(31)
# Out:
# accuracy is 21.21 % with k = 31

# %%
sv=SVM(X,label2,1/3)

# %%
sv.accurate()
# Out:
# accuracy is 69.7
